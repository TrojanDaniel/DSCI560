# %% [markdown]
# # calls the three scripts

# %% [markdown]
# First, run the gen_dataset_a.py which generates 1000 random numbers over the range 0-100 and stores the dataset into a json file named dataset_a.json

# %%
# %run gen_dataset_a.py

# %% [markdown]
# Second, run the gen_dataset_b.py which generates numbers from the original 1000 using the equation y=3x+6 and stores the dataset into a json file named dataset_b.json

# %%
# %run gen_dataset_b.py

# %% [markdown]
# Then, run the visualize.py which use dataset_a.json and dataset_b.json to visualize the results
# take dataset_a as x and dataset_b as y to plot graph and store it in .png format

# %%
# %run visualize.py
